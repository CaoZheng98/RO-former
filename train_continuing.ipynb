# %%
from models.transformer.transformer import Transformer  # 替换为你的模型模块路径
from data.dataset_ import DT_Dataset
from pathlib import Path
from utils.lr_strategies import SchedulerFactory
from utils.load_full_checkpoint import load_full_checkpoint
import torch
DS = DT_Dataset

# %%
# 设置设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# 创建模型实例
d_model = 64
seed = 42
max_len = 2000
pad_idx = 1
bos_len = 3
learning_rate = 1e-2
n_epochs = 200
batch_size = 100
out_fall_name = 'JHHXY'
Rainfall_intensity = 10
model = Transformer(src_len_max=max_len, trg_len_max=max_len, src_pad_idx=pad_idx, trg_pad_idx=pad_idx, d_src=1, d_trg=1, d_model=d_model, trg_size=1).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler_paras = {"scheduler_type": "warm_up", "warm_up_epochs": n_epochs * 0.25, "decay_rate": 0.99}
scheduler = SchedulerFactory.get_scheduler(optimizer, **scheduler_paras)
# 加载完整 checkpoint
checkpoint_path = "./runs/fine_tune_ml_2000_padidx_1_bos_len_3_lr_0.01_epochs_200_d_model_64_of_JHHXY_RI_10_batch_size_100/best_(max_nse)_56_-6.5539.pt"
load_info = load_full_checkpoint(checkpoint_path, model, optimizer, scheduler, device)

# %%
from torch.utils.data import DataLoader
from utils.collate_fn import collate_fn
ds_inference = DS()
batch_size = 100
inference_loader = DataLoader(dataset=ds_inference, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
saving_root = Path(
    "./runs") / f'fine_tune_ml_{max_len}_padidx_{pad_idx}_bos_len_{bos_len}_lr_{learning_rate}_epochs_{n_epochs}_d_model_{d_model}_of_{out_fall_name}_RI_{Rainfall_intensity}_batch_size_{batch_size}'
from utils.train_full import train_full
from utils.metrics import loss_func
train_full(model,inference_loader,inference_loader,optimizer,3,scheduler, loss_func, n_epochs, device, saving_root)
# Out:
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# ...

# %%
# Out:
# Parameters count:257473
# Training progress: 0 / 200
# Image saved as fine_tune_ml_2000_padidx_1_bos_len_3_lr_0.01_epochs_200_d_model_64_of_JHHXY_RI_10_batch_size_100\ground_truth_vs_pred0_200.png
# Training progress: 1 / 200
# Image saved as fine_tune_ml_2000_padidx_1_bos_len_3_lr_0.01_epochs_200_d_model_64_of_JHHXY_RI_10_batch_size_100\ground_truth_vs_pred0_201.png
# Training progress: 2 / 200
# Image saved as fine_tune_ml_2000_padidx_1_bos_len_3_lr_0.01_epochs_200_d_model_64_of_JHHXY_RI_10_batch_size_100\ground_truth_vs_pred0_202.png
# Training progress: 3 / 200
# Image saved as fine_tune_ml_2000_padidx_1_bos_len_3_lr_0.01_epochs_200_d_model_64_of_JHHXY_RI_10_batch_size_100\ground_truth_vs_pred0_203.png
# Training progress: 4 / 200
# Image saved as fine_tune_ml_2000_padidx_1_bos_len_3_lr_0.01_epochs_200_d_model_64_of_JHHXY_RI_10_batch_size_100\ground_truth_vs_pred0_204.png
# Training progress: 5 / 200
# ...
