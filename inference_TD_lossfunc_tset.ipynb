# %%
# 设置随机种子
from utils.set_seed import set_seed
# from pretrain import saving_root

seed = 42
set_seed(seed)

# %%
#NSE MODEL
from models.transformer.transformer import Transformer  # 替换为你的模型模块路径
from data.dataset import DT_Dataset
from pathlib import Path
from utils.lr_strategies import SchedulerFactory
from utils.load_full_checkpoint import load_full_checkpoint
import torch
DS = DT_Dataset
# 设置设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# 创建模型实例
d_model = 64
max_len = 2000
pad_idx = 1
learning_rate = 1e-2
n_epochs = 200
model_nse = Transformer(src_len_max=max_len, trg_len_max=max_len, src_pad_idx=pad_idx, trg_pad_idx=pad_idx, d_src=1, d_trg=1, d_model=d_model, trg_size=1).to(device)
optimizer = torch.optim.Adam(model_nse.parameters(), lr=learning_rate)
scheduler_paras = {"scheduler_type": "warm_up", "warm_up_epochs": n_epochs * 0.25, "decay_rate": 0.99}
scheduler = SchedulerFactory.get_scheduler(optimizer, **scheduler_paras)
# 加载完整 checkpoint
checkpoint_path = "./runs/TD_ml_2000_padidx_1_bos_len_3_lr_0.01_epochs_500_d_model_64_of_JHHHHC_RI_10_LF_nse_DATASET_f/best_(newest)_499_499.0000.pt"
load_info = load_full_checkpoint(checkpoint_path, model_nse, optimizer, scheduler, device)

# %%
#MSE MODEL
from models.transformer.transformer import Transformer  # 替换为你的模型模块路径
from data.dataset import DT_Dataset
from pathlib import Path
from utils.lr_strategies import SchedulerFactory
from utils.load_full_checkpoint import load_full_checkpoint
import torch
DS = DT_Dataset
# 设置设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# 创建模型实例
d_model = 64
max_len = 2000
pad_idx = 1
learning_rate = 1e-2
n_epochs = 200
model_mse = Transformer(src_len_max=max_len, trg_len_max=max_len, src_pad_idx=pad_idx, trg_pad_idx=pad_idx, d_src=1, d_trg=1, d_model=d_model, trg_size=1).to(device)
optimizer = torch.optim.Adam(model_mse.parameters(), lr=learning_rate)
scheduler_paras = {"scheduler_type": "warm_up", "warm_up_epochs": n_epochs * 0.25, "decay_rate": 0.99}
scheduler = SchedulerFactory.get_scheduler(optimizer, **scheduler_paras)
# 加载完整 checkpoint
checkpoint_path = "./runs/TD_ml_2000_padidx_1_bos_len_3_lr_0.01_epochs_500_d_model_64_of_JHHHHC_RI_10_LF_loss_func_mse_DATASET_f/best_(min_mse)_496_0.0000.pt"
load_info = load_full_checkpoint(checkpoint_path, model_mse, optimizer, scheduler, device)

# %%
#MSE+NSE MODEL
from models.transformer.transformer import Transformer  # 替换为你的模型模块路径
from data.dataset import DT_Dataset
from pathlib import Path
from utils.lr_strategies import SchedulerFactory
from utils.load_full_checkpoint import load_full_checkpoint
import torch
DS = DT_Dataset
# 设置设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# 创建模型实例
d_model = 64
max_len = 2000
pad_idx = 1
learning_rate = 1e-2
n_epochs = 200
model_mixed = Transformer(src_len_max=max_len, trg_len_max=max_len, src_pad_idx=pad_idx, trg_pad_idx=pad_idx, d_src=1, d_trg=1, d_model=d_model, trg_size=1).to(device)
optimizer = torch.optim.Adam(model_mixed.parameters(), lr=learning_rate)
scheduler_paras = {"scheduler_type": "warm_up", "warm_up_epochs": n_epochs * 0.25, "decay_rate": 0.99}
scheduler = SchedulerFactory.get_scheduler(optimizer, **scheduler_paras)
# 加载完整 checkpoint
checkpoint_path = "./runs/TD_ml_2000_padidx_1_bos_len_3_lr_0.01_epochs_500_d_model_64_of_JHHHHC_RI_10_LF_loss_func_NZ_DATASET_f/best_(newest)_499_499.0000.pt"
load_info = load_full_checkpoint(checkpoint_path, model_mixed, optimizer, scheduler, device)

# %%
#NSE_ENHANCED MODEL
from models.transformer.transformer import Transformer  # 替换为你的模型模块路径
from data.dataset import DT_Dataset
from pathlib import Path
from utils.lr_strategies import SchedulerFactory
from utils.load_full_checkpoint import load_full_checkpoint
import torch
DS = DT_Dataset
# 设置设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# 创建模型实例
d_model = 64
max_len = 2000
pad_idx = 1
learning_rate = 1e-2
n_epochs = 200
model_enhanced = Transformer(src_len_max=max_len, trg_len_max=max_len, src_pad_idx=pad_idx, trg_pad_idx=pad_idx, d_src=1, d_trg=1, d_model=d_model, trg_size=1).to(device)
optimizer = torch.optim.Adam(model_enhanced.parameters(), lr=learning_rate)
scheduler_paras = {"scheduler_type": "warm_up", "warm_up_epochs": n_epochs * 0.25, "decay_rate": 0.99}
scheduler = SchedulerFactory.get_scheduler(optimizer, **scheduler_paras)
# 加载完整 checkpoint
checkpoint_path = "./runs/TD_ml_2000_padidx_1_bos_len_3_lr_0.01_epochs_500_d_model_64_of_JHHHHC_RI_10_LF_loss_func_NSE_enhanced_DATASET_f/best_(newest)_499_499.0000.pt"
load_info = load_full_checkpoint(checkpoint_path, model_enhanced, optimizer, scheduler, device)

# %%
#ADVANCED MODEL
from models.transformer.transformer import Transformer  # 替换为你的模型模块路径
from data.dataset import DT_Dataset
from pathlib import Path
from utils.lr_strategies import SchedulerFactory
from utils.load_full_checkpoint import load_full_checkpoint
import torch
DS = DT_Dataset
# 设置设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# 创建模型实例
d_model = 64
max_len = 2000
pad_idx = 1
learning_rate = 1e-2
n_epochs = 200
model_advanced = Transformer(src_len_max=max_len, trg_len_max=max_len, src_pad_idx=pad_idx, trg_pad_idx=pad_idx, d_src=1, d_trg=1, d_model=d_model, trg_size=1).to(device)
optimizer = torch.optim.Adam(model_advanced.parameters(), lr=learning_rate)
scheduler_paras = {"scheduler_type": "warm_up", "warm_up_epochs": n_epochs * 0.25, "decay_rate": 0.99}
scheduler = SchedulerFactory.get_scheduler(optimizer, **scheduler_paras)
# 加载完整 checkpoint
checkpoint_path = "./runs/TD_ml_2000_padidx_1_bos_len_3_lr_0.01_epochs_500_d_model_64_of_JHHHHC_RI_10_LF_loss_func_advanced_DATASET_f/best_(newest)_499_499.0000.pt"
load_info = load_full_checkpoint(checkpoint_path, model_advanced, optimizer, scheduler, device)

# %%
# FILTED DATASET
from data.dataset import DT_Dataset
from torch.utils.data import DataLoader
from utils.collate_fn import collate_fn
# _________dataset________
DS = DT_Dataset
Rainfall_intensity = 10
out_fall_name = 'JHHHHC'
OI = 50
max_patience = 12
batch_size = 100
ds_train = DS(outfall_name = out_fall_name,  Rainfall_intensity = Rainfall_intensity,max_patience=max_patience)
train_loader = DataLoader(dataset=ds_train, batch_size=batch_size, shuffle=False,collate_fn=collate_fn)
ds_val = DS(outfall_name=out_fall_name,  Rainfall_intensity=Rainfall_intensity, max_patience=max_patience,type='val')
val_loader = DataLoader(dataset=ds_val, batch_size=batch_size, shuffle=False,collate_fn=collate_fn)
# Out:
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复
# 流量恢复超时: 13步未恢复

# %%
#INF_NSE
from torch import nn
from utils.metrics import calc_nse_torch
import torch
# set model to eval mode (important for dropout)
model_nse.eval()
bos_len = 3
batch_idx = 3  # 想要访问的批次索引
for i, (x_seq, y_seq, real_data) in enumerate(train_loader):
    if i == batch_idx:
        # 处理数据
        break
with torch.no_grad():
    #y_seq做了padding
    if x_seq.ndim == 2:
        x_seq = x_seq.unsqueeze(-1)
    if y_seq.ndim == 2:
        y_seq = y_seq.unsqueeze(-1)
    if real_data.ndim == 2:
        real_data = real_data.unsqueeze(-1)
    x_seq, y_seq, real_data = x_seq.to(device), y_seq.to(device),real_data.to(device)
    enc_inputs = x_seq
    batch_size = y_seq.size(0)
    trg_len = y_seq.size(1)
    n_labels = y_seq.size(2)
    dec_inputs = torch.zeros((batch_size, trg_len,n_labels)).to(device)
    dec_inputs[:,:bos_len,:] = y_seq[:,:bos_len,:]

    # get model predictions
    for i in range(bos_len, trg_len):
        decoder_predict = model_nse(enc_inputs, dec_inputs)
        dec_inputs[:, i, :] = decoder_predict[:, i - 1, :]
    y_hat_nse = dec_inputs[:, :, :]
    y_truth = real_data[:, :, :]

# %%
# INF_MSE
from torch import nn
from utils.metrics import calc_nse_torch
import torch
# set model to eval mode (important for dropout)
model_mse.eval()
bos_len = 3
batch_idx = 3  # 想要访问的批次索引
for i, (x_seq, y_seq, real_data) in enumerate(train_loader):
    if i == batch_idx:
        # 处理数据
        break
with torch.no_grad():
    #y_seq做了padding
    if x_seq.ndim == 2:
        x_seq = x_seq.unsqueeze(-1)
    if y_seq.ndim == 2:
        y_seq = y_seq.unsqueeze(-1)
    if real_data.ndim == 2:
        real_data = real_data.unsqueeze(-1)
    x_seq, y_seq, real_data = x_seq.to(device), y_seq.to(device),real_data.to(device)
    enc_inputs = x_seq
    batch_size = y_seq.size(0)
    trg_len = y_seq.size(1)
    n_labels = y_seq.size(2)
    dec_inputs = torch.zeros((batch_size, trg_len,n_labels)).to(device)
    dec_inputs[:,:bos_len,:] = y_seq[:,:bos_len,:]

    # get model predictions
    for i in range(bos_len, trg_len):
        decoder_predict = model_mse(enc_inputs, dec_inputs)
        dec_inputs[:, i, :] = decoder_predict[:, i - 1, :]
    y_hat_mse = dec_inputs[:, :, :]
    y_truth = real_data[:, :, :]

# %%
# INF_MIXED
from torch import nn
from utils.metrics import calc_nse_torch
import torch
# set model to eval mode (important for dropout)
model_mixed.eval()
bos_len = 3
batch_idx = 3  # 想要访问的批次索引
for i, (x_seq, y_seq, real_data) in enumerate(train_loader):
    if i == batch_idx:
        # 处理数据
        break
with torch.no_grad():
    #y_seq做了padding
    if x_seq.ndim == 2:
        x_seq = x_seq.unsqueeze(-1)
    if y_seq.ndim == 2:
        y_seq = y_seq.unsqueeze(-1)
    if real_data.ndim == 2:
        real_data = real_data.unsqueeze(-1)
    x_seq, y_seq, real_data = x_seq.to(device), y_seq.to(device),real_data.to(device)
    enc_inputs = x_seq
    batch_size = y_seq.size(0)
    trg_len = y_seq.size(1)
    n_labels = y_seq.size(2)
    dec_inputs = torch.zeros((batch_size, trg_len,n_labels)).to(device)
    dec_inputs[:,:bos_len,:] = y_seq[:,:bos_len,:]

    # get model predictions
    for i in range(bos_len, trg_len):
        decoder_predict = model_mixed(enc_inputs, dec_inputs)
        dec_inputs[:, i, :] = decoder_predict[:, i - 1, :]
    y_hat_mixed = dec_inputs[:, :, :]
    y_truth = real_data[:, :, :]

# %%
# INF_ENHANCED
from torch import nn
from utils.metrics import calc_nse_torch
import torch
# set model to eval mode (important for dropout)
model_enhanced.eval()
bos_len = 3
batch_idx = 3  # 想要访问的批次索引
for i, (x_seq, y_seq, real_data) in enumerate(train_loader):
    if i == batch_idx:
        # 处理数据
        break
with torch.no_grad():
    #y_seq做了padding
    if x_seq.ndim == 2:
        x_seq = x_seq.unsqueeze(-1)
    if y_seq.ndim == 2:
        y_seq = y_seq.unsqueeze(-1)
    if real_data.ndim == 2:
        real_data = real_data.unsqueeze(-1)
    x_seq, y_seq, real_data = x_seq.to(device), y_seq.to(device),real_data.to(device)
    enc_inputs = x_seq
    batch_size = y_seq.size(0)
    trg_len = y_seq.size(1)
    n_labels = y_seq.size(2)
    dec_inputs = torch.zeros((batch_size, trg_len,n_labels)).to(device)
    dec_inputs[:,:bos_len,:] = y_seq[:,:bos_len,:]

    # get model predictions
    for i in range(bos_len, trg_len):
        decoder_predict = model_enhanced(enc_inputs, dec_inputs)
        dec_inputs[:, i, :] = decoder_predict[:, i - 1, :]
    y_hat_enhanced = dec_inputs[:, :, :]
    y_truth = real_data[:, :, :]

# %%
# INF_ADVANCED
from torch import nn
from utils.metrics import calc_nse_torch
import torch
# set model to eval mode (important for dropout)
model_advanced.eval()
bos_len = 3
batch_idx = 3  # 想要访问的批次索引
for i, (x_seq, y_seq, real_data) in enumerate(train_loader):
    if i == batch_idx:
        # 处理数据
        break
with torch.no_grad():
    #y_seq做了padding
    if x_seq.ndim == 2:
        x_seq = x_seq.unsqueeze(-1)
    if y_seq.ndim == 2:
        y_seq = y_seq.unsqueeze(-1)
    if real_data.ndim == 2:
        real_data = real_data.unsqueeze(-1)
    x_seq, y_seq, real_data = x_seq.to(device), y_seq.to(device),real_data.to(device)
    enc_inputs = x_seq
    batch_size = y_seq.size(0)
    trg_len = y_seq.size(1)
    n_labels = y_seq.size(2)
    dec_inputs = torch.zeros((batch_size, trg_len,n_labels)).to(device)
    dec_inputs[:,:bos_len,:] = y_seq[:,:bos_len,:]

    # get model predictions
    for i in range(bos_len, trg_len):
        decoder_predict = model_advanced(enc_inputs, dec_inputs)
        dec_inputs[:, i, :] = decoder_predict[:, i - 1, :]
    y_hat_advanced = dec_inputs[:, :, :]
    y_truth = real_data[:, :, :]

# %%
from utils.draw_ import plot_multiple_inference_lft
plot_multiple_inference_lft(x_seq, y_hat_mixed,y_seq,'inference', pred_np1=y_hat_nse,pred_np2=y_hat_mse,pred_np4=y_hat_advanced,idx_list=[0,1,2,3,4,5],
                           figures_folder='figures_TD_LFT_inference_0', time_step='10 min', 
                           save=True)
# (rain_fall, pred, ground_truth, iter_,
#                             pred_np1=None, pred_np2=None, pred_np3=None,  # 新增多个预测结果参数
#                             pred_np4=None, pred_np5=None, idx_list=None,
#                             figures_folder='figures_jhhhhc_r10',
#                             time_step='10 min', save=False)


# plot_multiple_inference(x_seq, y_hat, y_seq, 'inference', idx_list=list(range(48,54)),
#                            figures_folder='figures_TD_inference', time_step='10 min', 
#                            save=False)

# %%
from utils.draw_ import plot_multiple_inference_lft
plot_multiple_inference_lft(x_seq, y_hat_enhanced,y_seq,'inference',idx_list=[0,1,2,3,4,5],
                           figures_folder='figures_TD_LFT_inference_1', time_step='10 min', 
                           save=True)

# %%
 # 16 22  27 28 38 39  42 46
